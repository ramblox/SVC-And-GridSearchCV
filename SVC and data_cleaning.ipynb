# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
data['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
data.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
X=data.drop('quality',axis=1)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y=data['quality']

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 548            12.4             0.350         0.49             2.6      0.079
# 355             6.7             0.750         0.01             2.4      0.078
# 1296            6.6             0.630         0.00             4.3      0.093
# 209            11.0             0.300         0.58             2.1      0.054
# 140             8.4             0.745         0.11             1.9      0.090
# ...             ...               ...          ...             ...        ...
# 1130            9.1             0.600         0.00             1.9      0.058
# 1294            8.2             0.635         0.10             2.1      0.073
# 860             7.2             0.620         0.06             2.7      0.077
# 1459            7.9             0.200         0.35             1.7      0.054
# 1126            5.8             0.290         0.26             1.7      0.063
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train_transform=scaler.fit_transform(X_train)

# %%
X_test_transform=scaler.transform(X_test)

# %%
print(scaler.mean_)
# Out:
# [ 8.30345472  0.53246499  0.26933707  2.54691877  0.08772736 15.91223156
#  46.76330532  0.99677933  3.31453782  0.65881419 10.41521942]

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(X_train_transform,y_train)
# Out:
# SVC()

# %%
model.score(X_train_transform,y_train)
# Out:
# 0.6778711484593838

# %%
y_predict=model.predict(X_test_transform)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.5984848484848485

# %% [markdown]
# ## Check with logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2=LogisticRegression()

# %%
model2.fit(X_train_transform,y_train)
# Out:
# LogisticRegression()

# %%
y_predict2=model2.predict(X_test_transform)

# %%
accuracy_score(y_test,y_predict2)
# Out:
# 0.571969696969697

# %% [markdown]
# https://raw.githubusercontent.com/srinivasav22/Graduate-Admission-Prediction/master/Admission_Predict_Ver1.1.csv

# %% [markdown]
# ## Task
# Increase accuracy of the svc model (wine quality dataset)
#
# Hyperparameter tuning (gridsearch cv)
#
# implement SVR admission prediction

# %% [markdown]
# https://discord.com/invite/wyEAPaQEBN

# %% [markdown]
# # Task1 starts here

# %% [markdown]
# ........

# %% [markdown]
# ...........
#
# ...........
#
# ...........
#
# ...........

# %%
X.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data:
    if plotnumber<=11 :     # as there are 9 columns in the data
        ax = plt.subplot(5,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
data['citric acid'].value_counts().plot(kind='pie',figsize=(10,10))

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=data, width= 0.5,ax=ax,  fliersize=3)

# %%
data_copy=data

# %%
data_copy.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
q=data_copy['fixed acidity'].quantile(0.98)

# %%
q
# Out:
# 12.7

# %%
sns.boxplot(data_copy['fixed acidity'])

# %%
data_copy=data_copy[data_copy['fixed acidity']<q]

# %%
data_copy
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.boxplot(data_copy['residual sugar'])

# %%
q=data_copy['residual sugar'].quantile(0.95)

# %%
q
# Out:
# 4.1

# %%
data_copy=data_copy[data_copy['residual sugar']<q]

# %%
sns.boxplot(data_copy['residual sugar'])

# %%
sns.boxplot(data_copy['free sulfur dioxide'])

# %%
q=data_copy['free sulfur dioxide'].quantile(0.98)

# %%
q
# Out:
# 40.00999999999999

# %%
data_copy=data_copy[data_copy['free sulfur dioxide']<q]

# %%
sns.boxplot(data_copy['free sulfur dioxide'])

# %%
sns.boxplot(data_copy['total sulfur dioxide'])

# %%
q=data_copy['total sulfur dioxide'].quantile(0.975)

# %%
q
# Out:
# 124.5

# %%
data_copy=data_copy[data_copy['total sulfur dioxide']<q]

# %%
sns.boxplot(data_copy['total sulfur dioxide'])

# %%
sns.boxplot(data_copy['sulphates'])

# %%
q=data_copy['sulphates'].quantile(0.975)

# %%
q
# Out:
# 1.06

# %%
data_copy=data_copy[data_copy['sulphates']<q]

# %%
sns.boxplot(data_copy['sulphates'])

# %%
sns.boxplot(data_copy['chlorides'])

# %%
q=data_copy['chlorides'].quantile(0.95)

# %%
q
# Out:
# 0.118

# %%
data_copy=data_copy[data_copy['chlorides']<q]

# %%
sns.boxplot(data_copy['chlorides'])

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=data_copy, width= 0.5,ax=ax,  fliersize=3)

# %%
data.shape
# Out:
# (1599, 12)

# %%
data_copy.shape
# Out:
# (1275, 12)

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in data_copy:
    if plotnumber<=11 :     # as there are 9 columns in the data
        ax = plt.subplot(5,5,plotnumber)
        sns.distplot(data_copy[column])
        plt.xlabel(column,fontsize=20)
        #plt.ylabel('Salary',fontsize=20)
    plotnumber+=1
plt.show()

# %%
data_copy.to_csv('Outlier_cleaned_wine.csv',index=False)
